# %%
##conda install --channel conda-forge pystan fbprophet
import pandas as pd
import fbprophet
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# %cd D:\e-Learning\Github\examples
# Out:
# D:\e-Learning\Github\examples

# %%
df=pd.read_csv('example_wp_log_peyton_manning.csv')

# %%
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
from fbprophet import Prophet

# %%
model=Prophet()

# %%
model.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
### Create future dates of 365 days which be will be appended to the original data
future_dates=model.make_future_dataframe(periods=365)

# %%
future_dates.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = model.predict(future_dates)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.208630    7.482157    8.927409
# 3266 2017-01-16  8.533648    7.788036    9.312620
# 3267 2017-01-17  8.321065    7.553088    9.054215
# 3268 2017-01-18  8.153693    7.409757    8.880504
# 3269 2017-01-19  8.165630    7.405732    8.942072

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)
